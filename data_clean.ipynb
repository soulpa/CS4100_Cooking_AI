# %%
import pandas as pd
import numpy as np 
data = pd.read_csv("data/test_recipes.csv")
# data = pd.read_csv("data/recipes.csv")
data.head(10)
# Out:
#    Row                               Name Prep Time Cook Time     Total Time  \
# 0    0  Indian Chicken Curry (Murgh Kari)   20 mins   40 mins          1 hrs
# 1    1                   Chicken Stir-Fry   20 mins   20 mins        40 mins
# 2    2                          Jambalaya   20 mins   45 mins   1 hrs 5 mins
# 3    3                      Chicken Katsu   10 mins   10 mins        20 mins
# 4    4       Simple Baked Chicken Breasts   10 mins   25 mins        35 mins
# 5    5                    Chicken Marsala   10 mins   20 mins        30 mins
# 6    6      Baked Garlic Parmesan Chicken   15 mins   30 mins        45 mins
# 7    7               Asian Orange Chicken   20 mins   20 mins  2 hrs 50 mins
# 8    8                Chicken Quesadillas   20 mins   25 mins        45 mins
# 9    9                Chicken Cordon Bleu   10 mins   35 mins        45 mins
#
#    Servings       Yield                                        Ingredients  \
# 0         6  6 servings  [{'quantity': '2', 'unit': 'pounds', 'name': '...
# 1         6         NaN  [{'quantity': '4', 'unit': 'cups', 'name': 'wa...
# 2         6  6 servings  [{'quantity': '2', 'unit': 'tablespoons', 'nam...
# 3         4  4 servings  [{'quantity': '4', 'unit': '', 'name': 'skinle...
# 4         4         NaN  [{'quantity': '4', 'unit': '(5 ounce)', 'name'...
# 5         4  4 servings  [{'quantity': '¼', 'unit': 'cup', 'name': 'all...
# 6         6  6 servings  [{'quantity': '2', 'unit': 'tablespoons', 'nam...
# 7         4         NaN  [{'quantity': '1 ½', 'unit': 'cups', 'name': '...
# 8        10         NaN  [{'quantity': '1', 'unit': 'pound', 'name': 's...
# 9         4  4 servings  [{'quantity': '', 'unit': '', 'name': 'nonstic...
#
#                                           Directions  \
# 0  ['Sprinkle the chicken breasts with 2 teaspoon...
# 1  ['Bring water and rice to a boil in a saucepan...
# 2  ['Heat 1 tablespoon of peanut oil in a large h...
# 3  ['Season the chicken breasts on both sides wit...
# 4  ['Preheat the oven to 400 degrees F (200 degre...
# 5  ['In a shallow dish or bowl, mix together the ...
# 6  ['Preheat oven to 350 degrees F (175 degrees C...
# 7  ['Combine water, rice vinegar, lemon juice, so...
# 8  ['Preheat the broiler. Lightly grease a baking...
# 9  ['Preheat oven to 350 degrees F (175 degrees C...
#
#                                                  url Additional Time
# 0  https://www.allrecipes.com/recipe/212721/india...             NaN
# 1  https://www.allrecipes.com/recipe/223382/chick...             NaN
# 2  https://www.allrecipes.com/recipe/31848/jambal...             NaN
# 3  https://www.allrecipes.com/recipe/72068/chicke...             NaN
# 4  https://www.allrecipes.com/recipe/240208/simpl...             NaN
# 5  https://www.allrecipes.com/recipe/8887/chicken...             NaN
# 6  https://www.allrecipes.com/recipe/55860/baked-...             NaN
# 7  https://www.allrecipes.com/recipe/61024/asian-...   2 hrs 10 mins
# 8  https://www.allrecipes.com/recipe/21659/chicke...             NaN
# 9  https://www.allrecipes.com/recipe/8495/chicken...             NaN

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 59 entries, 0 to 58
# Data columns (total 11 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Row              59 non-null     int64
#  1   Name             59 non-null     object
#  2   Prep Time        59 non-null     object
#  3   Cook Time        59 non-null     object
#  4   Total Time       59 non-null     object
#  5   Servings         59 non-null     int64
#  6   Yield            15 non-null     object
#  7   Ingredients      59 non-null     object
#  8   Directions       59 non-null     object
#  9   url              59 non-null     object
#  10  Additional Time  17 non-null     object
# dtypes: int64(2), object(9)
# memory usage: 5.2+ KB

# %%
# clean dataset

data = data.drop(data.columns[0], axis=1)

# %%
def convert_time_to_mins(time):
    if pd.isna(time):
        return np.nan
    
    time = time.lower().strip()
    split = time.split()

    # 3 possible formats:
    # x hrs y mins
    if len(split) == 4:
        return int(split[0]) * 60 + int(split[2])

    # x hrs
    if split[1] == "hrs":
        return int(split[0]) * 60
    
    # y mins
    if split[1] == "mins":
        return int(split[0])    
    
    return np.nan # shouldn't get here

# testing
print(convert_time_to_mins("1 hrs"))          # 120
print(convert_time_to_mins("40 mins"))        # 45
print(convert_time_to_mins("1 hrs 5 mins"))  # 90
# Out:
# 60
# 40
# 65

# %%
data["Prep Time"] = data["Prep Time"].apply(convert_time_to_mins).astype("Int64")
data["Cook Time"] = data["Cook Time"].apply(convert_time_to_mins).astype("Int64")
data["Total Time"] = data["Total Time"].apply(convert_time_to_mins).astype("Int64")
data["Additional Time"] = data["Additional Time"].apply(convert_time_to_mins).astype("Int64") # could remove

data.head(10)
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 59 entries, 0 to 58
# Data columns (total 10 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Name             59 non-null     object
#  1   Prep Time        59 non-null     Int64
#  2   Cook Time        59 non-null     Int64
#  3   Total Time       59 non-null     Int64
#  4   Servings         59 non-null     int64
#  5   Yield            15 non-null     object
#  6   Ingredients      59 non-null     object
#  7   Directions       59 non-null     object
#  8   url              59 non-null     object
#  9   Additional Time  17 non-null     Int64
# dtypes: Int64(4), int64(1), object(5)
# memory usage: 5.0+ KB

# %%
data['Servings'] = data['Servings'].astype('Int64')

print(data['Yield'].unique())
data = data.drop('Yield', axis=1)
data.info()
# Out:
# ['6 servings' nan '4 servings' '1 12-inch sandwich' '1 2-quart casserole'
#  '2 chicken breast halves' '8 chicken breasts' '1 9-inch casserole'
#  '1 9x13-inch casserole' '8 enchiladas' '6 sandwiches']
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 59 entries, 0 to 58
# Data columns (total 9 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Name             59 non-null     object
#  1   Prep Time        59 non-null     Int64
#  2   Cook Time        59 non-null     Int64
#  3   Total Time       59 non-null     Int64
#  4   Servings         59 non-null     Int64
#  5   Ingredients      59 non-null     object
#  6   Directions       59 non-null     object
#  7   url              59 non-null     object
#  8   Additional Time  17 non-null     Int64
# dtypes: Int64(5), object(4)
# memory usage: 4.6+ KB

# %%
import ast
data["Ingredients"] = data["Ingredients"].apply(
    lambda x: ast.literal_eval(x) if isinstance(x, str) else x
)
data["Directions"] = data["Directions"].apply(
    lambda x: ast.literal_eval(x) if isinstance(x, str) else x
)

data.head(10)
# Out:
#                                 Name  Prep Time  Cook Time  Total Time  \
# 0  Indian Chicken Curry (Murgh Kari)         20         40          60
# 1                   Chicken Stir-Fry         20         20          40
# 2                          Jambalaya         20         45          65
# 3                      Chicken Katsu         10         10          20
# 4       Simple Baked Chicken Breasts         10         25          35
# 5                    Chicken Marsala         10         20          30
# 6      Baked Garlic Parmesan Chicken         15         30          45
# 7               Asian Orange Chicken         20         20         170
# 8                Chicken Quesadillas         20         25          45
# 9                Chicken Cordon Bleu         10         35          45
#
#    Servings                                        Ingredients  \
# 0         6  [{'quantity': '2', 'unit': 'pounds', 'name': '...
# 1         6  [{'quantity': '4', 'unit': 'cups', 'name': 'wa...
# 2         6  [{'quantity': '2', 'unit': 'tablespoons', 'nam...
# 3         4  [{'quantity': '4', 'unit': '', 'name': 'skinle...
# 4         4  [{'quantity': '4', 'unit': '(5 ounce)', 'name'...
# 5         4  [{'quantity': '¼', 'unit': 'cup', 'name': 'all...
# 6         6  [{'quantity': '2', 'unit': 'tablespoons', 'nam...
# 7         4  [{'quantity': '1 ½', 'unit': 'cups', 'name': '...
# 8        10  [{'quantity': '1', 'unit': 'pound', 'name': 's...
# 9         4  [{'quantity': '', 'unit': '', 'name': 'nonstic...
#
#                                           Directions  \
# 0  [Sprinkle the chicken breasts with 2 teaspoons...
# 1  [Bring water and rice to a boil in a saucepan ...
# 2  [Heat 1 tablespoon of peanut oil in a large he...
# 3  [Season the chicken breasts on both sides with...
# 4  [Preheat the oven to 400 degrees F (200 degree...
# 5  [In a shallow dish or bowl, mix together the f...
# 6  [Preheat oven to 350 degrees F (175 degrees C)...
# 7  [Combine water, rice vinegar, lemon juice, soy...
# 8  [Preheat the broiler. Lightly grease a baking ...
# 9  [Preheat oven to 350 degrees F (175 degrees C)...
#
#                                                  url  Additional Time
# 0  https://www.allrecipes.com/recipe/212721/india...             <NA>
# 1  https://www.allrecipes.com/recipe/223382/chick...             <NA>
# 2  https://www.allrecipes.com/recipe/31848/jambal...             <NA>
# 3  https://www.allrecipes.com/recipe/72068/chicke...             <NA>
# 4  https://www.allrecipes.com/recipe/240208/simpl...             <NA>
# 5  https://www.allrecipes.com/recipe/8887/chicken...             <NA>
# 6  https://www.allrecipes.com/recipe/55860/baked-...             <NA>
# 7  https://www.allrecipes.com/recipe/61024/asian-...              130
# 8  https://www.allrecipes.com/recipe/21659/chicke...             <NA>
# 9  https://www.allrecipes.com/recipe/8495/chicken...             <NA>

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 59 entries, 0 to 58
# Data columns (total 9 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Name             59 non-null     object
#  1   Prep Time        59 non-null     Int64
#  2   Cook Time        59 non-null     Int64
#  3   Total Time       59 non-null     Int64
#  4   Servings         59 non-null     Int64
#  5   Ingredients      59 non-null     object
#  6   Directions       59 non-null     object
#  7   url              59 non-null     object
#  8   Additional Time  17 non-null     Int64
# dtypes: Int64(5), object(4)
# memory usage: 4.6+ KB

# %%
data.to_csv("data/clean_recipes.csv", index=False)

# %%
data[data["Name"] == "Easy Italian Chicken"].iloc[0]
# Out:
# Name                                            Easy Italian Chicken
# Prep Time                                                          5
# Cook Time                                                         60
# Total Time                                                       125
# Servings                                                           6
# Ingredients        [{'quantity': '1', 'unit': '(16 ounce) bottle'...
# Directions         [Pour salad dressing into a large resealable p...
# url                https://www.allrecipes.com/recipe/17745/easy-i...
# Additional Time                                                   60
# Name: 14, dtype: object
