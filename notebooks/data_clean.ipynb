# %%
import pandas as pd
import numpy as np 
data = pd.read_csv("data/test_recipes.csv")
# data = pd.read_csv("../data/recipes.csv")
data.head(10)
# Out:
#    Unnamed: 0                        recipe_name prep_time cook_time  \
# 0           0           Apple-Cranberry Crostada       NaN       NaN
# 1           1          Apple Pie by Grandma Ople   30 mins     1 hrs
# 2           2        Sarah's Homemade Applesauce   10 mins   15 mins
# 3           3                        Apple Crisp   30 mins   45 mins
# 4           4                  Apple Pie Filling   20 mins   20 mins
# 5           5  Easy Apple Crisp with Oat Topping   20 mins   40 mins
# 6           6                   Easy Apple Cider   10 mins     1 hrs
# 7           7              Apple-Cranberry Crisp   25 mins   40 mins
# 8           8      Old-Fashioned Apple Dumplings   30 mins     1 hrs
# 9           9              Southern Fried Apples   10 mins   10 mins
#
#       total_time  servings              yield  \
# 0            NaN         8  6 to 8 - servings
# 1  1 hrs 30 mins         8       1 9-inch pie
# 2        25 mins         4                NaN
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1090 entries, 0 to 1089
# Data columns (total 15 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Unnamed: 0    1090 non-null   int64
#  1   recipe_name   1090 non-null   object
#  2   prep_time     1039 non-null   object
#  3   cook_time     782 non-null    object
#  4   total_time    1045 non-null   object
#  5   servings      1090 non-null   int64
#  6   yield         879 non-null    object
#  7   ingredients   1090 non-null   object
#  8   directions    1090 non-null   object
#  9   rating        1090 non-null   float64
#  10  url           1090 non-null   object
#  11  cuisine_path  1090 non-null   object
#  12  nutrition     1090 non-null   object
#  13  timing        1090 non-null   object
#  14  img_src       1090 non-null   object
# dtypes: float64(1), int64(2), object(12)
# memory usage: 127.9+ KB

# %%
# clean dataset

data = data.drop(data.columns[0], axis=1)

# %%
def convert_time_to_mins(time):
    if pd.isna(time):
        return np.nan
    
    time = time.lower().strip()
    split = time.split()

    # 3 possible formats:
    # x hrs y mins
    if len(split) == 4:
        return int(split[0]) * 60 + int(split[2])

    # x hrs
    if split[1] == "hrs":
        return int(split[0]) * 60
    
    # y mins
    if split[1] == "mins":
        return int(split[0])    
    
    return np.nan # shouldn't get here

# testing
print(convert_time_to_mins("1 hrs"))          # 120
print(convert_time_to_mins("40 mins"))        # 45
print(convert_time_to_mins("1 hrs 5 mins"))  # 90
# Out:
# 60
# 40
# 65

# %%
data["Prep Time"] = data["Prep Time"].apply(convert_time_to_mins).astype("Int64")
data["Cook Time"] = data["Cook Time"].apply(convert_time_to_mins).astype("Int64")
data["Total Time"] = data["Total Time"].apply(convert_time_to_mins).astype("Int64")
data["Additional Time"] = data["Additional Time"].apply(convert_time_to_mins).astype("Int64") # could remove

data.head(10)
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1090 entries, 0 to 1089
# Data columns (total 14 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   recipe_name   1090 non-null   object
#  1   prep_time     1039 non-null   Int64
#  2   cook_time     782 non-null    Int64
#  3   total_time    1038 non-null   Int64
#  4   servings      1090 non-null   int64
#  5   yield         879 non-null    object
#  6   ingredients   1090 non-null   object
#  7   directions    1090 non-null   object
#  8   rating        1090 non-null   float64
#  9   url           1090 non-null   object
#  10  cuisine_path  1090 non-null   object
#  11  nutrition     1090 non-null   object
#  12  timing        1090 non-null   object
#  13  img_src       1090 non-null   object
# dtypes: Int64(3), float64(1), int64(1), object(9)
# memory usage: 122.5+ KB

# %%
data['Servings'] = data['Servings'].astype('Int64')

print(data['Yield'].unique())
data = data.drop('Yield', axis=1)
data.info()
# Out:
# ['6 to 8 - servings' '1 9-inch pie' nan '1 9x13-inch pan' '5 9-inch pies'
#  '1 8-inch crisp' '8 turnovers' '1 8-inch square dish' '4 cups' '1 gallon'
#  '7 quarts' '6 caramel apples' '1 9x13-inch cake' '4 hand pies' '6 cups'
#  '6 large muffins' '1 9x5-inch loaf' '1 8x8-inch dish' '12 muffins'
#  '4 servings' '4 pints' '1 8-inch pan' '2 apple roses' '2 12-ounce jars'
#  '1 dozen' '1 8-inch cake' '1 10-inch bundt cake' '1 cake' '60 pieces'
#  '2 9x13-inch cakes' '1 10-pound ham' '1 to 9 - inch cobbler' '3 cups'
#  '1 quart' '1 bowl' '1 pie' '48 servings' '1 - 9x13 inch dish'
#  '1 cocktail' '18 cookies' '1 to 9 - inch round cake' '4 half pints'
#  '1 8-inch dessert' '1 9x12-inch cake' '5 dozen' '12 servings'
#  '1 to 12 - x inch cake' '18 servings' '1 to 10 - inch ring' '1 tube cake'
#  '1 to 8 inch tube pan' '8 servings' '1 to 9 - inch pie' '2 dozen'
#  '1 9-inch cake' '6 to 10 servings' '2 cups' '4 half-pint jars'
#  '1 8-inch layer cake' '64 servings' '24 appetizers' '2 servings'
# ...

# %%
import ast
data["Ingredients"] = data["Ingredients"].apply(
    lambda x: ast.literal_eval(x) if isinstance(x, str) else x
)
data["Directions"] = data["Directions"].apply(
    lambda x: ast.literal_eval(x) if isinstance(x, str) else x
)

data.head(10)
# Out:
# Traceback (most recent call last):
#
#   File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages\IPython\core\interactiveshell.py:3699 in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#
#   Cell In[9], line 2
#     data["ingredients"] = data["ingredients"].apply(
#
#   File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages\pandas\core\series.py:4943 in apply
#     ).apply()
#
#   File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages\pandas\core\apply.py:1422 in apply
#     return self.apply_standard()
#
#   File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages\pandas\core\apply.py:1502 in apply_standard
#     mapped = obj._map_values(
#
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 59 entries, 0 to 58
# Data columns (total 9 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Name             59 non-null     object
#  1   Prep Time        59 non-null     Int64
#  2   Cook Time        59 non-null     Int64
#  3   Total Time       59 non-null     Int64
#  4   Servings         59 non-null     Int64
#  5   Ingredients      59 non-null     object
#  6   Directions       59 non-null     object
#  7   url              59 non-null     object
#  8   Additional Time  17 non-null     Int64
# dtypes: Int64(5), object(4)
# memory usage: 4.6+ KB

# %%
data.to_csv("data/clean_recipes.csv", index=False)

# %%
data[data["Name"] == "Easy Italian Chicken"].iloc[0]
# Out:
# Name                                            Easy Italian Chicken
# Prep Time                                                          5
# Cook Time                                                         60
# Total Time                                                       125
# Servings                                                           6
# Ingredients        [{'quantity': '1', 'unit': '(16 ounce) bottle'...
# Directions         [Pour salad dressing into a large resealable p...
# url                https://www.allrecipes.com/recipe/17745/easy-i...
# Additional Time                                                   60
# Name: 14, dtype: object
